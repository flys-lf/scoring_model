# %% [markdown]
# # FEATURE SELECTIONS

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import sklearn

import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv('input/df_preprocessed.csv')
df.shape
# Out:
# (307511, 144)

# %%
cat_cols = df.select_dtypes(include='object').columns.to_list()
print("nombre de variables catégorielle :", len(cat_cols), end="\n")
# Out:
# nombre de variables catégorielle : 9

# %%
cat_cols
# Out:
# ['CNT_CHILDREN',
#  'NAME_CONTRACT_TYPE',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'OCCUPATION_TYPE',
#  'WEEKDAY_APPR_PROCESS_START']

# %% [markdown]
# # Test Khi-2 : Sélection des variables catégorielles

# %%
y = df['TARGET']
chi_ls = []
for feature in cat_cols:
    
    # create contingency table
    c = pd.crosstab(y, df[feature])
    
    # chi_test
    p_value = chi2_contingency(c)[1]
    chi_ls.append(p_value)

# %% [markdown]
# H0 : Les variables X et Y sont indépendantes.
# Au seuil de 1%, si p-value <= 0.01 alors hypothèse nulle rejetée.
# Ici la variable 'WEEKDAY_APPR_PROCESS_START' sera supprimée

# %%
sns.set(style="ticks", rc={'figure.figsize': (10, 10)}, palette="hls")

df_pvalue = pd.DataFrame(chi_ls, index=df.select_dtypes(include='object').columns, columns=['p_value']).sort_values(by='p_value', ascending=True)

pd.set_option('display.float_format', '{:,.3f}'.format)
print(df_pvalue)

df_pvalue.plot.barh()
plt.xlabel('p value')
plt.title('Chi-square test')
plt.show()
# Out:
#                             p_value
# NAME_INCOME_TYPE              0.000
# OCCUPATION_TYPE               0.000
# NAME_EDUCATION_TYPE           0.000
# NAME_FAMILY_STATUS            0.000
# NAME_CONTRACT_TYPE            0.000
# NAME_HOUSING_TYPE             0.000
# CNT_CHILDREN                  0.000
# NAME_TYPE_SUITE               0.000
# WEEKDAY_APPR_PROCESS_START    0.017

# %%
df.drop(labels='WEEKDAY_APPR_PROCESS_START', axis=1, inplace=True)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 143 columns):
#  #    Column                                        Non-Null Count   Dtype
# ---   ------                                        --------------   -----
#  0    SK_ID_CURR                                    307511 non-null  float64
#  1    CNT_CHILDREN                                  307511 non-null  object
#  2    AMT_INCOME_TOTAL                              307511 non-null  float64
#  3    AMT_CREDIT                                    307511 non-null  float64
#  4    AMT_ANNUITY                                   307511 non-null  float64
#  5    REGION_POPULATION_RELATIVE                    307511 non-null  float64
#  6    DAYS_BIRTH                                    307511 non-null  float64
#  7    DAYS_EMPLOYED                                 307511 non-null  float64
#  8    DAYS_REGISTRATION                             307511 non-null  float64
#  9    DAYS_ID_PUBLISH                               307511 non-null  float64
#  10   FLAG_EMP_PHONE                                307511 non-null  float64
#  11   FLAG_WORK_PHONE                               307511 non-null  float64
#  12   FLAG_PHONE                                    307511 non-null  float64
#  13   FLAG_EMAIL                                    307511 non-null  float64
#  14   CNT_FAM_MEMBERS                               307511 non-null  float64
#  15   REGION_RATING_CLIENT                          307511 non-null  float64
#  16   REGION_RATING_CLIENT_W_CITY                   307511 non-null  float64
#  17   HOUR_APPR_PROCESS_START                       307511 non-null  float64
#  18   REG_REGION_NOT_LIVE_REGION                    307511 non-null  float64
#  19   REG_REGION_NOT_WORK_REGION                    307511 non-null  float64
#  20   LIVE_REGION_NOT_WORK_REGION                   307511 non-null  float64
#  21   REG_CITY_NOT_LIVE_CITY                        307511 non-null  float64
#  22   REG_CITY_NOT_WORK_CITY                        307511 non-null  float64
#  23   LIVE_CITY_NOT_WORK_CITY                       307511 non-null  float64
#  24   EXT_SOURCE_2                                  307511 non-null  float64
#  25   EXT_SOURCE_3                                  307511 non-null  float64
#  26   YEARS_BEGINEXPLUATATION_AVG                   307511 non-null  float64
#  27   FLOORSMAX_AVG                                 307511 non-null  float64
#  28   TOTALAREA_MODE                                307511 non-null  float64
#  29   DAYS_LAST_PHONE_CHANGE                        307511 non-null  float64
#  30   FLAG_DOCUMENT_3                               307511 non-null  float64
#  31   FLAG_DOCUMENT_6                               307511 non-null  float64
#  32   FLAG_DOCUMENT_8                               307511 non-null  float64
#  33   AMT_REQ_CREDIT_BUREAU_HOUR                    307511 non-null  float64
#  34   AMT_REQ_CREDIT_BUREAU_DAY                     307511 non-null  float64
#  35   AMT_REQ_CREDIT_BUREAU_WEEK                    307511 non-null  float64
#  36   AMT_REQ_CREDIT_BUREAU_MON                     307511 non-null  float64
#  37   AMT_REQ_CREDIT_BUREAU_QRT                     307511 non-null  float64
#  38   AMT_REQ_CREDIT_BUREAU_YEAR                    307511 non-null  float64
#  39   NAME_CONTRACT_TYPE                            307511 non-null  object
#  40   CODE_GENDER                                   307511 non-null  int64
#  41   FLAG_OWN_CAR                                  307511 non-null  int64
#  42   FLAG_OWN_REALTY                               307511 non-null  int64
#  43   NAME_TYPE_SUITE                               307511 non-null  object
#  44   NAME_INCOME_TYPE                              307511 non-null  object
#  45   NAME_EDUCATION_TYPE                           307511 non-null  object
#  46   NAME_FAMILY_STATUS                            307511 non-null  object
#  47   NAME_HOUSING_TYPE                             307511 non-null  object
#  48   OCCUPATION_TYPE                               307511 non-null  object
#  49   DAYS_EMPLOYED_PERC                            307511 non-null  float64
#  50   INCOME_CREDIT_PERC                            307511 non-null  float64
#  51   INCOME_PER_PERSON                             307511 non-null  float64
#  52   ANNUITY_INCOME_PERC                           307511 non-null  float64
#  53   PAYMENT_RATE                                  307511 non-null  float64
#  54   TARGET                                        307511 non-null  int64
#  55   PREV_AMT_ANNUITY_MEAN                         307511 non-null  float64
#  56   PREV_AMT_APPLICATION_MEAN                     307511 non-null  float64
#  57   PREV_AMT_CREDIT_MEAN                          307511 non-null  float64
#  58   PREV_APP_CREDIT_PERC_MEAN                     307511 non-null  float64
#  59   PREV_APP_CREDIT_PERC_VAR                      307511 non-null  float64
#  60   PREV_HOUR_APPR_PROCESS_START_MEAN             307511 non-null  float64
#  61   PREV_DAYS_DECISION_MEAN                       307511 non-null  float64
#  62   PREV_CNT_PAYMENT_MEAN                         307511 non-null  float64
#  63   PREV_CNT_PAYMENT_SUM                          307511 non-null  float64
#  64   PREV_NAME_CONTRACT_STATUS_Approved_MEAN       307511 non-null  float64
#  65   PREV_NAME_CONTRACT_STATUS_Canceled_MEAN       307511 non-null  float64
#  66   PREV_NAME_CONTRACT_STATUS_Refused_MEAN        307511 non-null  float64
#  67   PREV_NAME_CONTRACT_STATUS_Unused_offer_MEAN   307511 non-null  float64
#  68   PREV_NAME_CONTRACT_TYPE_Cash_loans_MEAN       307511 non-null  float64
#  69   PREV_NAME_CONTRACT_TYPE_Consumer_loans_MEAN   307511 non-null  float64
#  70   PREV_NAME_CONTRACT_TYPE_Revolving_loans_MEAN  307511 non-null  float64
#  71   PREV_NAME_CONTRACT_TYPE_XNA_MEAN              307511 non-null  float64
#  72   APPROVED_AMT_ANNUITY_MEAN                     307511 non-null  float64
#  73   APPROVED_AMT_APPLICATION_MEAN                 307511 non-null  float64
#  74   APPROVED_AMT_CREDIT_MEAN                      307511 non-null  float64
#  75   APPROVED_APP_CREDIT_PERC_MEAN                 307511 non-null  float64
#  76   APPROVED_APP_CREDIT_PERC_VAR                  307511 non-null  float64
#  77   APPROVED_HOUR_APPR_PROCESS_START_MEAN         307511 non-null  float64
#  78   APPROVED_DAYS_DECISION_MEAN                   307511 non-null  float64
#  79   APPROVED_CNT_PAYMENT_MEAN                     307511 non-null  float64
#  80   APPROVED_CNT_PAYMENT_SUM                      307511 non-null  float64
#  81   REFUSED_AMT_ANNUITY_MEAN                      307511 non-null  float64
#  82   REFUSED_AMT_APPLICATION_MEAN                  307511 non-null  float64
#  83   REFUSED_AMT_CREDIT_MEAN                       307511 non-null  float64
#  84   REFUSED_APP_CREDIT_PERC_MEAN                  307511 non-null  float64
#  85   REFUSED_APP_CREDIT_PERC_VAR                   307511 non-null  float64
#  86   REFUSED_HOUR_APPR_PROCESS_START_MEAN          307511 non-null  float64
#  87   REFUSED_DAYS_DECISION_MEAN                    307511 non-null  float64
#  88   REFUSED_CNT_PAYMENT_MEAN                      307511 non-null  float64
#  89   REFUSED_CNT_PAYMENT_SUM                       307511 non-null  float64
#  90   BURO_DAYS_CREDIT_MEAN                         307511 non-null  float64
#  91   BURO_AMT_CREDIT_SUM_MEAN                      307511 non-null  float64
#  92   BURO_AMT_CREDIT_SUM_SUM                       307511 non-null  float64
#  93   BURO_MONTHS_BALANCE_MIN_MIN                   307511 non-null  float64
#  94   BURO_MONTHS_BALANCE_MAX_MAX                   307511 non-null  float64
#  95   BURO_MONTHS_BALANCE_SIZE_MEAN                 307511 non-null  float64
#  96   BURO_MONTHS_BALANCE_SIZE_SUM                  307511 non-null  float64
#  97   BURO_CREDIT_ACTIVE_Active_MEAN                307511 non-null  float64
#  98   BURO_CREDIT_ACTIVE_Closed_MEAN                307511 non-null  float64
#  99   BURO_CREDIT_ACTIVE_Sold_or_Bad_debt_MEAN      307511 non-null  float64
#  100  BURO_CREDIT_TYPE_Consumer_credit_MEAN         307511 non-null  float64
#  101  BURO_CREDIT_TYPE_Credit_card_MEAN             307511 non-null  float64
#  102  BURO_CREDIT_TYPE_Other_MEAN                   307511 non-null  float64
#  103  BURO_STATUS_CLOSED_MEAN_MEAN                  307511 non-null  float64
#  104  BURO_STATUS_NO_DPD_MEAN_MEAN                  307511 non-null  float64
#  105  BURO_STATUS_WITH_DPD_MEAN_MEAN                307511 non-null  float64
#  106  BURO_STATUS_X_MEAN_MEAN                       307511 non-null  float64
#  107  ACTIVE_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  108  ACTIVE_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  109  ACTIVE_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  110  ACTIVE_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  111  ACTIVE_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  112  ACTIVE_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  113  ACTIVE_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  114  CLOSED_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  115  CLOSED_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  116  CLOSED_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  117  CLOSED_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  118  CLOSED_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  119  CLOSED_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  120  CLOSED_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  121  CC_MONTHS_BALANCE_MEAN                        307511 non-null  float64
#  122  CC_MONTHS_BALANCE_SUM                         307511 non-null  float64
#  123  CC_AMT_BALANCE_MEAN                           307511 non-null  float64
#  124  CC_AMT_BALANCE_SUM                            307511 non-null  float64
#  125  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN               307511 non-null  float64
#  126  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                307511 non-null  float64
#  127  CC_AMT_DRAWINGS_CURRENT_MEAN                  307511 non-null  float64
#  128  CC_AMT_DRAWINGS_CURRENT_SUM                   307511 non-null  float64
#  129  CC_COUNT                                      307511 non-null  float64
#  130  INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE         307511 non-null  float64
#  131  INSTAL_DPD_MAX                                307511 non-null  float64
#  132  INSTAL_DPD_MEAN                               307511 non-null  float64
#  133  INSTAL_DBD_MAX                                307511 non-null  float64
#  134  INSTAL_DBD_MEAN                               307511 non-null  float64
#  135  INSTAL_PAYMENT_PERC_MAX                       307511 non-null  float64
#  136  INSTAL_PAYMENT_PERC_MEAN                      307511 non-null  float64
#  137  INSTAL_PAYMENT_DIFF_MEAN                      307511 non-null  float64
#  138  INSTAL_AMT_PAYMENT_MEAN                       307511 non-null  float64
#  139  INSTAL_AMT_PAYMENT_SUM                        307511 non-null  float64
#  140  INSTAL_COUNT                                  307511 non-null  float64
#  141  POS_MONTHS_BALANCE_MEAN                       307511 non-null  float64
#  142  POS_COUNT                                     307511 non-null  float64
# dtypes: float64(131), int64(4), object(8)
# memory usage: 335.5+ MB

# %%
y = df['TARGET']

df.drop(labels='TARGET', axis=1, inplace=True)

# %% [markdown]
# # Variables Catégorielles Ordinales

# %%
# Map to numeric CNT_CHILDREN
df['CNT_CHILDREN'] = df['CNT_CHILDREN'].astype('category')

# %%
# df.info(verbose=True)
df['CNT_CHILDREN'] = df['CNT_CHILDREN'].cat.as_ordered()
print(df['CNT_CHILDREN'], end="\n\n\n")
df['CNT_CHILDREN'] = df['CNT_CHILDREN'].cat.codes
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 307506    0
# 307507    0
# 307508    0
# 307509    0
# 307510    0
# Name: CNT_CHILDREN, Length: 307511, dtype: category
# Categories (3, object): ['0' < '1' < '2 or more']

# %%
df['CNT_CHILDREN'].value_counts()
# Out:
# CNT_CHILDREN
# 0    215371
# 1     61119
# 2     31021
# Name: count, dtype: int64

# %%
cat_columns = df.select_dtypes(include='object').columns.to_list()
print(cat_columns)
# Out:
# ['NAME_CONTRACT_TYPE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE']

# %%
df = pd.get_dummies(df, columns=cat_columns, drop_first=True)

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 166 columns):
#  #    Column                                        Non-Null Count   Dtype
# ---   ------                                        --------------   -----
#  0    SK_ID_CURR                                    307511 non-null  float64
#  1    CNT_CHILDREN                                  307511 non-null  int8
#  2    AMT_INCOME_TOTAL                              307511 non-null  float64
#  3    AMT_CREDIT                                    307511 non-null  float64
#  4    AMT_ANNUITY                                   307511 non-null  float64
#  5    REGION_POPULATION_RELATIVE                    307511 non-null  float64
#  6    DAYS_BIRTH                                    307511 non-null  float64
#  7    DAYS_EMPLOYED                                 307511 non-null  float64
#  8    DAYS_REGISTRATION                             307511 non-null  float64
#  9    DAYS_ID_PUBLISH                               307511 non-null  float64
#  10   FLAG_EMP_PHONE                                307511 non-null  float64
#  11   FLAG_WORK_PHONE                               307511 non-null  float64
#  12   FLAG_PHONE                                    307511 non-null  float64
#  13   FLAG_EMAIL                                    307511 non-null  float64
#  14   CNT_FAM_MEMBERS                               307511 non-null  float64
#  15   REGION_RATING_CLIENT                          307511 non-null  float64
#  16   REGION_RATING_CLIENT_W_CITY                   307511 non-null  float64
#  17   HOUR_APPR_PROCESS_START                       307511 non-null  float64
#  18   REG_REGION_NOT_LIVE_REGION                    307511 non-null  float64
#  19   REG_REGION_NOT_WORK_REGION                    307511 non-null  float64
#  20   LIVE_REGION_NOT_WORK_REGION                   307511 non-null  float64
#  21   REG_CITY_NOT_LIVE_CITY                        307511 non-null  float64
#  22   REG_CITY_NOT_WORK_CITY                        307511 non-null  float64
#  23   LIVE_CITY_NOT_WORK_CITY                       307511 non-null  float64
#  24   EXT_SOURCE_2                                  307511 non-null  float64
#  25   EXT_SOURCE_3                                  307511 non-null  float64
#  26   YEARS_BEGINEXPLUATATION_AVG                   307511 non-null  float64
#  27   FLOORSMAX_AVG                                 307511 non-null  float64
#  28   TOTALAREA_MODE                                307511 non-null  float64
#  29   DAYS_LAST_PHONE_CHANGE                        307511 non-null  float64
#  30   FLAG_DOCUMENT_3                               307511 non-null  float64
#  31   FLAG_DOCUMENT_6                               307511 non-null  float64
#  32   FLAG_DOCUMENT_8                               307511 non-null  float64
#  33   AMT_REQ_CREDIT_BUREAU_HOUR                    307511 non-null  float64
#  34   AMT_REQ_CREDIT_BUREAU_DAY                     307511 non-null  float64
#  35   AMT_REQ_CREDIT_BUREAU_WEEK                    307511 non-null  float64
#  36   AMT_REQ_CREDIT_BUREAU_MON                     307511 non-null  float64
#  37   AMT_REQ_CREDIT_BUREAU_QRT                     307511 non-null  float64
#  38   AMT_REQ_CREDIT_BUREAU_YEAR                    307511 non-null  float64
#  39   CODE_GENDER                                   307511 non-null  int64
#  40   FLAG_OWN_CAR                                  307511 non-null  int64
#  41   FLAG_OWN_REALTY                               307511 non-null  int64
#  42   DAYS_EMPLOYED_PERC                            307511 non-null  float64
#  43   INCOME_CREDIT_PERC                            307511 non-null  float64
#  44   INCOME_PER_PERSON                             307511 non-null  float64
#  45   ANNUITY_INCOME_PERC                           307511 non-null  float64
#  46   PAYMENT_RATE                                  307511 non-null  float64
#  47   PREV_AMT_ANNUITY_MEAN                         307511 non-null  float64
#  48   PREV_AMT_APPLICATION_MEAN                     307511 non-null  float64
#  49   PREV_AMT_CREDIT_MEAN                          307511 non-null  float64
#  50   PREV_APP_CREDIT_PERC_MEAN                     307511 non-null  float64
#  51   PREV_APP_CREDIT_PERC_VAR                      307511 non-null  float64
#  52   PREV_HOUR_APPR_PROCESS_START_MEAN             307511 non-null  float64
#  53   PREV_DAYS_DECISION_MEAN                       307511 non-null  float64
#  54   PREV_CNT_PAYMENT_MEAN                         307511 non-null  float64
#  55   PREV_CNT_PAYMENT_SUM                          307511 non-null  float64
#  56   PREV_NAME_CONTRACT_STATUS_Approved_MEAN       307511 non-null  float64
#  57   PREV_NAME_CONTRACT_STATUS_Canceled_MEAN       307511 non-null  float64
#  58   PREV_NAME_CONTRACT_STATUS_Refused_MEAN        307511 non-null  float64
#  59   PREV_NAME_CONTRACT_STATUS_Unused_offer_MEAN   307511 non-null  float64
#  60   PREV_NAME_CONTRACT_TYPE_Cash_loans_MEAN       307511 non-null  float64
#  61   PREV_NAME_CONTRACT_TYPE_Consumer_loans_MEAN   307511 non-null  float64
#  62   PREV_NAME_CONTRACT_TYPE_Revolving_loans_MEAN  307511 non-null  float64
#  63   PREV_NAME_CONTRACT_TYPE_XNA_MEAN              307511 non-null  float64
#  64   APPROVED_AMT_ANNUITY_MEAN                     307511 non-null  float64
#  65   APPROVED_AMT_APPLICATION_MEAN                 307511 non-null  float64
#  66   APPROVED_AMT_CREDIT_MEAN                      307511 non-null  float64
#  67   APPROVED_APP_CREDIT_PERC_MEAN                 307511 non-null  float64
#  68   APPROVED_APP_CREDIT_PERC_VAR                  307511 non-null  float64
#  69   APPROVED_HOUR_APPR_PROCESS_START_MEAN         307511 non-null  float64
#  70   APPROVED_DAYS_DECISION_MEAN                   307511 non-null  float64
#  71   APPROVED_CNT_PAYMENT_MEAN                     307511 non-null  float64
#  72   APPROVED_CNT_PAYMENT_SUM                      307511 non-null  float64
#  73   REFUSED_AMT_ANNUITY_MEAN                      307511 non-null  float64
#  74   REFUSED_AMT_APPLICATION_MEAN                  307511 non-null  float64
#  75   REFUSED_AMT_CREDIT_MEAN                       307511 non-null  float64
#  76   REFUSED_APP_CREDIT_PERC_MEAN                  307511 non-null  float64
#  77   REFUSED_APP_CREDIT_PERC_VAR                   307511 non-null  float64
#  78   REFUSED_HOUR_APPR_PROCESS_START_MEAN          307511 non-null  float64
#  79   REFUSED_DAYS_DECISION_MEAN                    307511 non-null  float64
#  80   REFUSED_CNT_PAYMENT_MEAN                      307511 non-null  float64
#  81   REFUSED_CNT_PAYMENT_SUM                       307511 non-null  float64
#  82   BURO_DAYS_CREDIT_MEAN                         307511 non-null  float64
#  83   BURO_AMT_CREDIT_SUM_MEAN                      307511 non-null  float64
#  84   BURO_AMT_CREDIT_SUM_SUM                       307511 non-null  float64
#  85   BURO_MONTHS_BALANCE_MIN_MIN                   307511 non-null  float64
#  86   BURO_MONTHS_BALANCE_MAX_MAX                   307511 non-null  float64
#  87   BURO_MONTHS_BALANCE_SIZE_MEAN                 307511 non-null  float64
#  88   BURO_MONTHS_BALANCE_SIZE_SUM                  307511 non-null  float64
#  89   BURO_CREDIT_ACTIVE_Active_MEAN                307511 non-null  float64
#  90   BURO_CREDIT_ACTIVE_Closed_MEAN                307511 non-null  float64
#  91   BURO_CREDIT_ACTIVE_Sold_or_Bad_debt_MEAN      307511 non-null  float64
#  92   BURO_CREDIT_TYPE_Consumer_credit_MEAN         307511 non-null  float64
#  93   BURO_CREDIT_TYPE_Credit_card_MEAN             307511 non-null  float64
#  94   BURO_CREDIT_TYPE_Other_MEAN                   307511 non-null  float64
#  95   BURO_STATUS_CLOSED_MEAN_MEAN                  307511 non-null  float64
#  96   BURO_STATUS_NO_DPD_MEAN_MEAN                  307511 non-null  float64
#  97   BURO_STATUS_WITH_DPD_MEAN_MEAN                307511 non-null  float64
#  98   BURO_STATUS_X_MEAN_MEAN                       307511 non-null  float64
#  99   ACTIVE_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  100  ACTIVE_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  101  ACTIVE_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  102  ACTIVE_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  103  ACTIVE_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  104  ACTIVE_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  105  ACTIVE_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  106  CLOSED_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  107  CLOSED_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  108  CLOSED_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  109  CLOSED_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  110  CLOSED_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  111  CLOSED_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  112  CLOSED_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  113  CC_MONTHS_BALANCE_MEAN                        307511 non-null  float64
#  114  CC_MONTHS_BALANCE_SUM                         307511 non-null  float64
#  115  CC_AMT_BALANCE_MEAN                           307511 non-null  float64
#  116  CC_AMT_BALANCE_SUM                            307511 non-null  float64
#  117  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN               307511 non-null  float64
#  118  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                307511 non-null  float64
#  119  CC_AMT_DRAWINGS_CURRENT_MEAN                  307511 non-null  float64
#  120  CC_AMT_DRAWINGS_CURRENT_SUM                   307511 non-null  float64
#  121  CC_COUNT                                      307511 non-null  float64
#  122  INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE         307511 non-null  float64
#  123  INSTAL_DPD_MAX                                307511 non-null  float64
#  124  INSTAL_DPD_MEAN                               307511 non-null  float64
#  125  INSTAL_DBD_MAX                                307511 non-null  float64
#  126  INSTAL_DBD_MEAN                               307511 non-null  float64
#  127  INSTAL_PAYMENT_PERC_MAX                       307511 non-null  float64
#  128  INSTAL_PAYMENT_PERC_MEAN                      307511 non-null  float64
#  129  INSTAL_PAYMENT_DIFF_MEAN                      307511 non-null  float64
#  130  INSTAL_AMT_PAYMENT_MEAN                       307511 non-null  float64
#  131  INSTAL_AMT_PAYMENT_SUM                        307511 non-null  float64
#  132  INSTAL_COUNT                                  307511 non-null  float64
#  133  POS_MONTHS_BALANCE_MEAN                       307511 non-null  float64
#  134  POS_COUNT                                     307511 non-null  float64
#  135  NAME_CONTRACT_TYPE_Revolving loans            307511 non-null  bool
#  136  NAME_TYPE_SUITE_Other                         307511 non-null  bool
#  137  NAME_TYPE_SUITE_Unaccompanied                 307511 non-null  bool
#  138  NAME_INCOME_TYPE_Other                        307511 non-null  bool
#  139  NAME_INCOME_TYPE_Pensioner or Unemployed      307511 non-null  bool
#  140  NAME_INCOME_TYPE_State servant                307511 non-null  bool
#  141  NAME_INCOME_TYPE_Working                      307511 non-null  bool
#  142  NAME_EDUCATION_TYPE_Secondary or Lower        307511 non-null  bool
#  143  NAME_FAMILY_STATUS_Married                    307511 non-null  bool
#  144  NAME_FAMILY_STATUS_Separated                  307511 non-null  bool
#  145  NAME_FAMILY_STATUS_Single / not married       307511 non-null  bool
#  146  NAME_FAMILY_STATUS_Unknown                    307511 non-null  bool
#  147  NAME_FAMILY_STATUS_Widow                      307511 non-null  bool
#  148  NAME_HOUSING_TYPE_Other                       307511 non-null  bool
#  149  OCCUPATION_TYPE_Cleaning staff                307511 non-null  bool
#  150  OCCUPATION_TYPE_Cooking staff                 307511 non-null  bool
#  151  OCCUPATION_TYPE_Core staff                    307511 non-null  bool
#  152  OCCUPATION_TYPE_Drivers                       307511 non-null  bool
#  153  OCCUPATION_TYPE_HR staff                      307511 non-null  bool
#  154  OCCUPATION_TYPE_High skill tech staff         307511 non-null  bool
#  155  OCCUPATION_TYPE_IT staff                      307511 non-null  bool
#  156  OCCUPATION_TYPE_Laborers                      307511 non-null  bool
#  157  OCCUPATION_TYPE_Low-skill Laborers            307511 non-null  bool
#  158  OCCUPATION_TYPE_Managers                      307511 non-null  bool
#  159  OCCUPATION_TYPE_Medicine staff                307511 non-null  bool
#  160  OCCUPATION_TYPE_Private service staff         307511 non-null  bool
#  161  OCCUPATION_TYPE_Realty agents                 307511 non-null  bool
#  162  OCCUPATION_TYPE_Sales staff                   307511 non-null  bool
#  163  OCCUPATION_TYPE_Secretaries                   307511 non-null  bool
#  164  OCCUPATION_TYPE_Security staff                307511 non-null  bool
#  165  OCCUPATION_TYPE_Waiters/barmen staff          307511 non-null  bool
# dtypes: bool(31), float64(131), int64(3), int8(1)
# memory usage: 323.8 MB

# %% [markdown]
# # Remove inf values

# %%
df = df.replace((np.inf, -np.inf), 0).reset_index(drop=True)

# %%
df['TARGET'] = y

# %%
df.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 167 columns):
#  #    Column                                        Non-Null Count   Dtype
# ---   ------                                        --------------   -----
#  0    SK_ID_CURR                                    307511 non-null  float64
#  1    CNT_CHILDREN                                  307511 non-null  int8
#  2    AMT_INCOME_TOTAL                              307511 non-null  float64
#  3    AMT_CREDIT                                    307511 non-null  float64
#  4    AMT_ANNUITY                                   307511 non-null  float64
#  5    REGION_POPULATION_RELATIVE                    307511 non-null  float64
#  6    DAYS_BIRTH                                    307511 non-null  float64
#  7    DAYS_EMPLOYED                                 307511 non-null  float64
#  8    DAYS_REGISTRATION                             307511 non-null  float64
#  9    DAYS_ID_PUBLISH                               307511 non-null  float64
#  10   FLAG_EMP_PHONE                                307511 non-null  float64
#  11   FLAG_WORK_PHONE                               307511 non-null  float64
#  12   FLAG_PHONE                                    307511 non-null  float64
#  13   FLAG_EMAIL                                    307511 non-null  float64
#  14   CNT_FAM_MEMBERS                               307511 non-null  float64
#  15   REGION_RATING_CLIENT                          307511 non-null  float64
#  16   REGION_RATING_CLIENT_W_CITY                   307511 non-null  float64
#  17   HOUR_APPR_PROCESS_START                       307511 non-null  float64
#  18   REG_REGION_NOT_LIVE_REGION                    307511 non-null  float64
#  19   REG_REGION_NOT_WORK_REGION                    307511 non-null  float64
#  20   LIVE_REGION_NOT_WORK_REGION                   307511 non-null  float64
#  21   REG_CITY_NOT_LIVE_CITY                        307511 non-null  float64
#  22   REG_CITY_NOT_WORK_CITY                        307511 non-null  float64
#  23   LIVE_CITY_NOT_WORK_CITY                       307511 non-null  float64
#  24   EXT_SOURCE_2                                  307511 non-null  float64
#  25   EXT_SOURCE_3                                  307511 non-null  float64
#  26   YEARS_BEGINEXPLUATATION_AVG                   307511 non-null  float64
#  27   FLOORSMAX_AVG                                 307511 non-null  float64
#  28   TOTALAREA_MODE                                307511 non-null  float64
#  29   DAYS_LAST_PHONE_CHANGE                        307511 non-null  float64
#  30   FLAG_DOCUMENT_3                               307511 non-null  float64
#  31   FLAG_DOCUMENT_6                               307511 non-null  float64
#  32   FLAG_DOCUMENT_8                               307511 non-null  float64
#  33   AMT_REQ_CREDIT_BUREAU_HOUR                    307511 non-null  float64
#  34   AMT_REQ_CREDIT_BUREAU_DAY                     307511 non-null  float64
#  35   AMT_REQ_CREDIT_BUREAU_WEEK                    307511 non-null  float64
#  36   AMT_REQ_CREDIT_BUREAU_MON                     307511 non-null  float64
#  37   AMT_REQ_CREDIT_BUREAU_QRT                     307511 non-null  float64
#  38   AMT_REQ_CREDIT_BUREAU_YEAR                    307511 non-null  float64
#  39   CODE_GENDER                                   307511 non-null  int64
#  40   FLAG_OWN_CAR                                  307511 non-null  int64
#  41   FLAG_OWN_REALTY                               307511 non-null  int64
#  42   DAYS_EMPLOYED_PERC                            307511 non-null  float64
#  43   INCOME_CREDIT_PERC                            307511 non-null  float64
#  44   INCOME_PER_PERSON                             307511 non-null  float64
#  45   ANNUITY_INCOME_PERC                           307511 non-null  float64
#  46   PAYMENT_RATE                                  307511 non-null  float64
#  47   PREV_AMT_ANNUITY_MEAN                         307511 non-null  float64
#  48   PREV_AMT_APPLICATION_MEAN                     307511 non-null  float64
#  49   PREV_AMT_CREDIT_MEAN                          307511 non-null  float64
#  50   PREV_APP_CREDIT_PERC_MEAN                     307511 non-null  float64
#  51   PREV_APP_CREDIT_PERC_VAR                      307511 non-null  float64
#  52   PREV_HOUR_APPR_PROCESS_START_MEAN             307511 non-null  float64
#  53   PREV_DAYS_DECISION_MEAN                       307511 non-null  float64
#  54   PREV_CNT_PAYMENT_MEAN                         307511 non-null  float64
#  55   PREV_CNT_PAYMENT_SUM                          307511 non-null  float64
#  56   PREV_NAME_CONTRACT_STATUS_Approved_MEAN       307511 non-null  float64
#  57   PREV_NAME_CONTRACT_STATUS_Canceled_MEAN       307511 non-null  float64
#  58   PREV_NAME_CONTRACT_STATUS_Refused_MEAN        307511 non-null  float64
#  59   PREV_NAME_CONTRACT_STATUS_Unused_offer_MEAN   307511 non-null  float64
#  60   PREV_NAME_CONTRACT_TYPE_Cash_loans_MEAN       307511 non-null  float64
#  61   PREV_NAME_CONTRACT_TYPE_Consumer_loans_MEAN   307511 non-null  float64
#  62   PREV_NAME_CONTRACT_TYPE_Revolving_loans_MEAN  307511 non-null  float64
#  63   PREV_NAME_CONTRACT_TYPE_XNA_MEAN              307511 non-null  float64
#  64   APPROVED_AMT_ANNUITY_MEAN                     307511 non-null  float64
#  65   APPROVED_AMT_APPLICATION_MEAN                 307511 non-null  float64
#  66   APPROVED_AMT_CREDIT_MEAN                      307511 non-null  float64
#  67   APPROVED_APP_CREDIT_PERC_MEAN                 307511 non-null  float64
#  68   APPROVED_APP_CREDIT_PERC_VAR                  307511 non-null  float64
#  69   APPROVED_HOUR_APPR_PROCESS_START_MEAN         307511 non-null  float64
#  70   APPROVED_DAYS_DECISION_MEAN                   307511 non-null  float64
#  71   APPROVED_CNT_PAYMENT_MEAN                     307511 non-null  float64
#  72   APPROVED_CNT_PAYMENT_SUM                      307511 non-null  float64
#  73   REFUSED_AMT_ANNUITY_MEAN                      307511 non-null  float64
#  74   REFUSED_AMT_APPLICATION_MEAN                  307511 non-null  float64
#  75   REFUSED_AMT_CREDIT_MEAN                       307511 non-null  float64
#  76   REFUSED_APP_CREDIT_PERC_MEAN                  307511 non-null  float64
#  77   REFUSED_APP_CREDIT_PERC_VAR                   307511 non-null  float64
#  78   REFUSED_HOUR_APPR_PROCESS_START_MEAN          307511 non-null  float64
#  79   REFUSED_DAYS_DECISION_MEAN                    307511 non-null  float64
#  80   REFUSED_CNT_PAYMENT_MEAN                      307511 non-null  float64
#  81   REFUSED_CNT_PAYMENT_SUM                       307511 non-null  float64
#  82   BURO_DAYS_CREDIT_MEAN                         307511 non-null  float64
#  83   BURO_AMT_CREDIT_SUM_MEAN                      307511 non-null  float64
#  84   BURO_AMT_CREDIT_SUM_SUM                       307511 non-null  float64
#  85   BURO_MONTHS_BALANCE_MIN_MIN                   307511 non-null  float64
#  86   BURO_MONTHS_BALANCE_MAX_MAX                   307511 non-null  float64
#  87   BURO_MONTHS_BALANCE_SIZE_MEAN                 307511 non-null  float64
#  88   BURO_MONTHS_BALANCE_SIZE_SUM                  307511 non-null  float64
#  89   BURO_CREDIT_ACTIVE_Active_MEAN                307511 non-null  float64
#  90   BURO_CREDIT_ACTIVE_Closed_MEAN                307511 non-null  float64
#  91   BURO_CREDIT_ACTIVE_Sold_or_Bad_debt_MEAN      307511 non-null  float64
#  92   BURO_CREDIT_TYPE_Consumer_credit_MEAN         307511 non-null  float64
#  93   BURO_CREDIT_TYPE_Credit_card_MEAN             307511 non-null  float64
#  94   BURO_CREDIT_TYPE_Other_MEAN                   307511 non-null  float64
#  95   BURO_STATUS_CLOSED_MEAN_MEAN                  307511 non-null  float64
#  96   BURO_STATUS_NO_DPD_MEAN_MEAN                  307511 non-null  float64
#  97   BURO_STATUS_WITH_DPD_MEAN_MEAN                307511 non-null  float64
#  98   BURO_STATUS_X_MEAN_MEAN                       307511 non-null  float64
#  99   ACTIVE_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  100  ACTIVE_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  101  ACTIVE_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  102  ACTIVE_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  103  ACTIVE_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  104  ACTIVE_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  105  ACTIVE_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  106  CLOSED_DAYS_CREDIT_MEAN                       307511 non-null  float64
#  107  CLOSED_AMT_CREDIT_SUM_MEAN                    307511 non-null  float64
#  108  CLOSED_AMT_CREDIT_SUM_SUM                     307511 non-null  float64
#  109  CLOSED_MONTHS_BALANCE_MIN_MIN                 307511 non-null  float64
#  110  CLOSED_MONTHS_BALANCE_MAX_MAX                 307511 non-null  float64
#  111  CLOSED_MONTHS_BALANCE_SIZE_MEAN               307511 non-null  float64
#  112  CLOSED_MONTHS_BALANCE_SIZE_SUM                307511 non-null  float64
#  113  CC_MONTHS_BALANCE_MEAN                        307511 non-null  float64
#  114  CC_MONTHS_BALANCE_SUM                         307511 non-null  float64
#  115  CC_AMT_BALANCE_MEAN                           307511 non-null  float64
#  116  CC_AMT_BALANCE_SUM                            307511 non-null  float64
#  117  CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN               307511 non-null  float64
#  118  CC_AMT_CREDIT_LIMIT_ACTUAL_SUM                307511 non-null  float64
#  119  CC_AMT_DRAWINGS_CURRENT_MEAN                  307511 non-null  float64
#  120  CC_AMT_DRAWINGS_CURRENT_SUM                   307511 non-null  float64
#  121  CC_COUNT                                      307511 non-null  float64
#  122  INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE         307511 non-null  float64
#  123  INSTAL_DPD_MAX                                307511 non-null  float64
#  124  INSTAL_DPD_MEAN                               307511 non-null  float64
#  125  INSTAL_DBD_MAX                                307511 non-null  float64
#  126  INSTAL_DBD_MEAN                               307511 non-null  float64
#  127  INSTAL_PAYMENT_PERC_MAX                       307511 non-null  float64
#  128  INSTAL_PAYMENT_PERC_MEAN                      307511 non-null  float64
#  129  INSTAL_PAYMENT_DIFF_MEAN                      307511 non-null  float64
#  130  INSTAL_AMT_PAYMENT_MEAN                       307511 non-null  float64
#  131  INSTAL_AMT_PAYMENT_SUM                        307511 non-null  float64
#  132  INSTAL_COUNT                                  307511 non-null  float64
#  133  POS_MONTHS_BALANCE_MEAN                       307511 non-null  float64
#  134  POS_COUNT                                     307511 non-null  float64
#  135  NAME_CONTRACT_TYPE_Revolving loans            307511 non-null  bool
#  136  NAME_TYPE_SUITE_Other                         307511 non-null  bool
#  137  NAME_TYPE_SUITE_Unaccompanied                 307511 non-null  bool
#  138  NAME_INCOME_TYPE_Other                        307511 non-null  bool
#  139  NAME_INCOME_TYPE_Pensioner or Unemployed      307511 non-null  bool
#  140  NAME_INCOME_TYPE_State servant                307511 non-null  bool
#  141  NAME_INCOME_TYPE_Working                      307511 non-null  bool
#  142  NAME_EDUCATION_TYPE_Secondary or Lower        307511 non-null  bool
#  143  NAME_FAMILY_STATUS_Married                    307511 non-null  bool
#  144  NAME_FAMILY_STATUS_Separated                  307511 non-null  bool
#  145  NAME_FAMILY_STATUS_Single / not married       307511 non-null  bool
#  146  NAME_FAMILY_STATUS_Unknown                    307511 non-null  bool
#  147  NAME_FAMILY_STATUS_Widow                      307511 non-null  bool
#  148  NAME_HOUSING_TYPE_Other                       307511 non-null  bool
#  149  OCCUPATION_TYPE_Cleaning staff                307511 non-null  bool
#  150  OCCUPATION_TYPE_Cooking staff                 307511 non-null  bool
#  151  OCCUPATION_TYPE_Core staff                    307511 non-null  bool
#  152  OCCUPATION_TYPE_Drivers                       307511 non-null  bool
#  153  OCCUPATION_TYPE_HR staff                      307511 non-null  bool
#  154  OCCUPATION_TYPE_High skill tech staff         307511 non-null  bool
#  155  OCCUPATION_TYPE_IT staff                      307511 non-null  bool
#  156  OCCUPATION_TYPE_Laborers                      307511 non-null  bool
#  157  OCCUPATION_TYPE_Low-skill Laborers            307511 non-null  bool
#  158  OCCUPATION_TYPE_Managers                      307511 non-null  bool
#  159  OCCUPATION_TYPE_Medicine staff                307511 non-null  bool
#  160  OCCUPATION_TYPE_Private service staff         307511 non-null  bool
#  161  OCCUPATION_TYPE_Realty agents                 307511 non-null  bool
#  162  OCCUPATION_TYPE_Sales staff                   307511 non-null  bool
#  163  OCCUPATION_TYPE_Secretaries                   307511 non-null  bool
#  164  OCCUPATION_TYPE_Security staff                307511 non-null  bool
#  165  OCCUPATION_TYPE_Waiters/barmen staff          307511 non-null  bool
#  166  TARGET                                        307511 non-null  int64
# dtypes: bool(31), float64(131), int64(4), int8(1)
# memory usage: 326.1 MB

# %% [markdown]
# # Export DF

# %%
df.to_csv('input/df_final.csv', encoding='utf-8', index=None)

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 307511 entries, 0 to 307510
# Series name: TARGET
# Non-Null Count   Dtype
# --------------   -----
# 307511 non-null  int64
# dtypes: int64(1)
# memory usage: 2.3 MB

# %% [markdown]
# # Split Train Data : Train, Test, Validation

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, y, stratify=y, test_size=0.3, random_state=101)

X_train.shape, X_test.shape
# Out:
# ((215257, 166), (92254, 166))

# %% [markdown]
# # Scaling des variables

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df.drop(labels=['SK_ID_CURR'], axis=1))

X_train_scaled = scaler.transform(X_train.drop(labels='SK_ID_CURR', axis=1))
X_test_scaled = scaler.transform(X_test.drop(labels='SK_ID_CURR', axis=1))

# %%
df.columns.to_series()[np.isinf(df).any()]
# Out:
# Series([], dtype: object)

# %%
# vérification
X_train_scaled.mean(), X_train_scaled.std()
# Out:
# (np.float64(0.22191359115058235), np.float64(0.3553878991205184))

# %% [markdown]
# # RFE : Recursive Feature Selection

# %%
sel_ = RFE(RandomForestClassifier(n_estimators=10, random_state=101))
sel_.fit(X_train_scaled, y_train)

# %%
sel_.get_support()
